# %% [markdown]
# #  版本確認
# #PYTHON 3.7
# #tensorflow==2.0.0
# #keras==2.5.4

# %%
import sys
print(sys.version)
print(sys.executable)
import tensorflow as tf
tf.__version__
# Out:
# 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# C:\ProgramData\Anaconda3\python.exe
# '2.0.0'

# %% [markdown]
# # import 函式庫

# %%
import numpy as np
import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()
import os
from sklearn.model_selection import train_test_split
import random
import keras
from tensorflow.python.framework import ops
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPool2D,MaxPooling2D,GlobalAveragePooling2D,AveragePooling2D,Input, concatenate
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
import itertools
from keras.models import Model,load_model
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import tensorflow.keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # DATA資料讀取

# %%
def get_data(k1_n):
    if k1_n == 1:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_10'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_10.dat'
    if k1_n == 2:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_20'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_20.dat'
    if k1_n == 3:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_30'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_30.dat'
    if k1_n == 4:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_40'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_40.dat'
    if k1_n == 5:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_50'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_AAI_ACtableNV_1_1_1_7_1_1_50.dat'
    
    if k1_n == 6:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_10'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_10.dat'
    if k1_n == 7:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_20'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_20.dat'
    if k1_n == 8:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_30'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_30.dat'
    if k1_n == 9:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_40'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_40.dat'
    if k1_n == 10:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_50'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-272623_AAI_ACtableNV_1_1_1_7_1_1_50.dat'
  
    if k1_n == 11:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_10'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_10.dat'
    if k1_n == 12:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_20'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_20.dat'
    if k1_n == 13:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_30'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_30.dat'
    if k1_n == 14:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_40'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_40.dat'
    if k1_n == 15:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_50'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_AAI_ACtableNV_1_1_1_7_1_1_50.dat'
    
    
    if k1_n == 16:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_10'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_10.dat'
    if k1_n == 17:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_20'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_20.dat'
    if k1_n == 18:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_30'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_30.dat'
    if k1_n == 19:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_40'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_40.dat'
    if k1_n == 20:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_50'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_AAI_ACtableNV_1_1_1_7_1_1_50.dat'
        
    if k1_n == 21:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_10'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_10.dat'
    if k1_n == 22:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_20'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_20.dat'
    if k1_n == 23:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_30'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_30.dat'
    if k1_n == 24:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_40'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_40.dat'
    if k1_n == 25:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_50'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_AAI_ACtableNV_1_1_1_7_1_1_50.dat'
        
        
    data_path = './272623/data/'
    train_path = data_path+data
    return train_path,ver

# %% [markdown]
# # ONE_HOT 編碼轉換

# %%
def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1

    return one_hot_encode

# %% [markdown]
# # 資料前處理
# 1.data資料分割
# 2.np.array.reshape
# 3.one_hot轉換

# %%
def deal_data(train_path):
    y_train= list()
    X_train= list()
    f = open(train_path,'r')
    s = f.read()
    f.close()
    data_train = s.split("\n")
    data_train.pop()
    random.shuffle(data_train)
    #print(data_train[0])
    for i in data_train:
        data_t = i.split(" ",1)
        y_train.append(data_t[0])
        X_train.append(data_t[1])
        #print(data_t[0])
        #print(data_t[1])
    data_x_train = list()
    for i in range(0,len(X_train)):
        data_t2 = X_train[i].split(" ")
        data_t2.pop()
        #print(len(data_t2))
        data_x_train.append(np.zeros( len(data_t2) ))
        for i_2 in data_t2:
            temp = i_2.split(":")
            temp[0] = int(temp[0])-1
            temp[1] = float(temp[1])
            data_x_train[i][temp[0]] = temp[1]
            #print(type(temp[0]) )
            #print(type(temp[1]) )
    X_train = np.array(data_x_train)
    y_train_label = np.array(y_train)
        
    #X_test = np.array(data_x_test)
    #y_test_label = np.array(y_test)
    
    #print(X_train.shape)
    #print(y_train_label.shape)
    #print(X_test.shape)
    #print(y_test_label.shape)
    
    len_type = int( (len(data_x_train[0])/14)) 

    
    X_train = np.reshape(X_train, [-1,7,len_type,2])
    #X_test = np.reshape(X_test, [-1,2,len_type,len_type])
    #X_test = np.swapaxes(X_test,1,3)
    y_train_onehot = to_categorical(y_train_label)
    #y_test_onehot = to_categorical(y_test_label)
    print(X_train.shape)
    print(y_train_onehot.shape)
    #print(X_test.shape)
    #print(y_test_onehot.shape)
    return len_type,X_train,y_train_onehot

# %% [markdown]
# # Model 建立

# %%
def model_lt2(len_type,drop_rate): 
    ops.reset_default_graph()
    keras.backend.clear_session()
    n_classes = 2  
    n_width = 7
    n_height = len_type
    n_depth = 2
    n_inputs = n_width * n_height * n_depth  # total pixels

    model = Sequential()
    model.add(Dense(1, input_shape=(n_width,n_height,n_depth)))
        
    model.add(Flatten())
    model.add(Dropout(rate = drop_rate))
    
    model.add(Dense(units=1024, activation='relu'))
    model.add(Dropout(rate = drop_rate))
    
    model.add(Dense(units=512, activation='relu'))
    model.add(Dropout(rate = drop_rate))
        
    model.add(Dense(units=256, activation='relu'))
    model.add(Dropout(rate = drop_rate))
        
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(rate = drop_rate))
        
    model.add(Dense(units=64, activation='relu'))
    model.add(Dropout(rate = drop_rate))
    
    model.add(Dense(units=32, activation='relu'))
    model.add(Dropout(rate = drop_rate))
        
    model.add(Dense(units=16, activation='relu'))
    model.add(Dropout(rate = drop_rate))
    
    model.add(Dense(units=8, activation='relu'))
    model.add(Dropout(rate = drop_rate))
        
    model.add(Dense(units=n_classes, activation='softmax'))
    #model.summary()

    return model

# %%
def test_Drop(len_type,rate): 
    batch_size = 100
    epochs = 1000
    num_classes = 2
    weight_decay = 1e-5
    DNN_model = model_lt2(len_type,rate)
    DNN_model.compile(optimizer=Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08),loss = 'categorical_crossentropy',metrics=['accuracy'])
    es=EarlyStopping(
            monitor='val_accuracy',
            patience=100,
            verbose=0,
            restore_best_weights=True
    )
    history = DNN_model.fit(
            X_train,
            y_train_onehot,
            batch_size=batch_size,
            epochs = epochs,
            callbacks=[es],
            validation_split = 0.1,
            verbose=1
    )
    return max(history.history['accuracy'])

# %%
batch_size = 100
epochs = 10000
num_classes = 2
weight_decay = 1e-5

for k in range(1,26):
    train_path,ver = get_data(k)
    len_type,X_train,y_train_onehot = deal_data(train_path)
    drop_arr = np.zeros(4)
    #for drop_r in range(1,4):
    #    drop_arr[drop_r] = test_Drop(len_type,drop_r*0.1)
    #print(len_type,np.argmax(drop_arr)*0.1)
    DNN_model = model_lt2(len_type,np.argmax(drop_arr)*0.1 )
    
    patience = [200,400,600,800,1000]
    for p in patience:
        model_path = './model/DNN_lt/'+ver+'p='+str(p)+'.hdf5'
        DNN_model.compile(optimizer=Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08),loss = 'categorical_crossentropy',metrics=['accuracy'])
    
        es=EarlyStopping(
            monitor='val_accuracy',
            patience=p,
            verbose=0,
            restore_best_weights=True
        )
        mc=ModelCheckpoint(
            model_path,
            monitor='val_accuracy',
            verbose=1,
            save_best_only=True,
            save_weights_only=False,
            mode='max',
            period=1
        )
        
    
        history = DNN_model.fit(
            X_train,
            y_train_onehot,
            batch_size=batch_size,
            epochs = epochs,
            callbacks=[es,mc],
            validation_split = 0.1,
            verbose=1
        )
        
        
        with open(model_path+'_train_log.txt',"w") as f:
            f.write('Patience:' + str(p) + '\n')
            f.write('Train accuracy:' + str(max(history.history['accuracy']) ) + '\n')
            f.write('Val accuracy:' + str(max(history.history['val_accuracy']) ) + '\n')
            f.write('Drop rate:' + str(np.argmax(drop_arr)*0.1) + '\n')
# Out:
# (6462, 7, 40, 2)
# (6462, 2)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 7, 40, 1)          3
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 280)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 280)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              287744
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# ...
