# %% [markdown]
# #  版本確認
# #PYTHON 3.7
# #tensorflow==2.0.0
# #keras==2.5.4

# %%
import sys
print(sys.version)
print(sys.executable)
import tensorflow as tf
tf.__version__
# Out:
# 3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]
# C:\Users\lab401\.conda\envs\tensorflow_py37\python.exe
# '2.0.0'

# %% [markdown]
# # import 函式庫

# %%
import numpy as np
import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()
import os
from sklearn.model_selection import train_test_split
import random
import keras
from tensorflow.python.framework import ops
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPool2D,MaxPooling2D,GlobalAveragePooling2D,AveragePooling2D,Input, concatenate
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
import itertools
from keras.models import Model,load_model
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import tensorflow.keras.backend as K

# %% [markdown]
# # DATA資料讀取

# %%
def get_data(k1_n,RFE):

    if k1_n == 1:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-test-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt2'
    if k1_n == 2:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-test-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt3'    
    if k1_n == 3:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt4'
        data = '272623-10.5-11.0-test-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt4'

    if k1_n == 4:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-test-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt2'
    if k1_n == 5:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-test-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt3'    
    if k1_n == 6:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt4'
        data = '272623-10.5-11.0-test-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt4'
    
    if k1_n == 7:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2'
    if k1_n == 8:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3'    
    if k1_n == 9:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt4'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt4'

    if k1_n == 10:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2'
    if k1_n == 11:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3'    
    if k1_n == 12:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt4'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt4'

    if k1_n == 13:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2'
    if k1_n == 14:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3'    
    if k1_n == 15:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt4'
        data = '272623-10.5-11.0-test-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt4'
        
    data_path = './272623/data/'
    ver = ver+'_RFE_'+str(RFE)
    data = data+'_RFE_'+str(RFE)
    
    test_path = data_path+data+'.dat'
    model_path ='./model/DNN_RFE/'+ver+'.hdf5'
    return test_path,model_path

# %% [markdown]
# # ONE_HOT 編碼轉換

# %%
def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1

    return one_hot_encode

# %% [markdown]
# # 資料前處理
# 1.data資料分割
# 2.np.array.reshape
# 3.one_hot轉換

# %%
def deal_data(train_path):
    y_test= list()
    X_test= list()
    f = open(test_path,'r')
    s = f.read()
    f.close()
    data_test = s.split("\n")
    data_test.pop()
    random.shuffle(data_test)

    for i in data_test:
        data_t = i.split(" ",1)
        y_test.append(data_t[0])
        X_test.append(data_t[1])
        #print(data_t[0])
        #print(data_t[1])
    data_x_test = list()
    for i in range(0,len(X_test)):
        data_t2 = X_test[i].split(" ")
        data_t2.pop()
        #print(len(data_t2))
        data_x_test.append(np.zeros( len(data_t2) ))
        for i_2 in data_t2:
            temp = i_2.split(":")
            temp[0] = int(temp[0])-1
            temp[1] = float(temp[1])
            data_x_test[i][temp[0]] = temp[1]
            #print(type(temp[0]) )
            #print(type(temp[1]) )
    X_test = np.array(data_x_test)
    y_test_label = np.array(y_test)
        
    len_type = int( (len(data_x_test[0]))/2) 


    X_test = np.reshape(X_test, [-1,len_type,2,1])
    y_test_onehot = to_categorical(y_test_label)

    print(X_test.shape)
    print(y_test_onehot.shape)
    return len_type,X_test,y_test_onehot

# %%
for k in range(10,17):
    if(k%3 == 0) :continue
    test_path,model_path = get_data(k,100)
    len_type,X_test,y_test_onehot = deal_data(test_path)
    
    model = load_model(model_path)
    y_pred =  model.predict(X_test,verbose=1)
    
    # 數值評估
    y_len = len(y_pred)
    y_pred_class = np.zeros((y_len,2),dtype=np.int)
    for i in range(0,y_len):
        if (y_pred[i][0] > y_pred[i][1]):
            y_pred_class[i][0] = 1
        else:
            y_pred_class[i][1] = 1
    
    TP=0
    FP=0
    TN=0
    FN=0
    acc=0
    Sen=0
    Pre=0
    
    for i in range(0,y_len):
        if(y_pred_class[i][0] == y_test_onehot[i][0]):
            if(y_pred_class[i][0] == 0):
                TP += 1
            else:
                TN +=1
        else:
            if(y_pred_class[i][0] == 1):
                FP += 1
            else:
                FN +=1
    acc = (TP+TN)/(TP+TN+FP+FN)
    if(TP != 0):Sen = TP/(TP+FN)
    if(TP != 0):Pre = TP/(TP+FP)
    '''
    print(TP)
    print(TN)
    print(FP)
    print(FN)
    print(acc)
    print(Sen)
    print(Pre)
    '''
    print('Model:',model_path)
    print('Test accuracy:', acc)
    
    with open(model_path+'_result.txt',"w") as f:
        f.write('Test accuracy:' + str(acc) + '\n')
        f.write('Test TP:' + str(TP) + '\n')
        f.write('Test FP:' + str(FP) + '\n')
        f.write('Test TN:' + str(TN) + '\n')
        f.write('Test FN:' + str(FN) + '\n')
        f.write('Test Sen:' + str(Sen) + '\n')
        f.write('Test Pre:' + str(Pre) + '\n')
# Out:
# (1694, 50, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 1s 487us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2_RFE_100.hdf5
# Test accuracy: 0.8713105076741441
# (1694, 50, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 100us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3_RFE_100.hdf5
# Test accuracy: 0.9144037780401417
# (1694, 50, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 100us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2_RFE_100.hdf5
# Test accuracy: 0.8919716646989374
# (1694, 50, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 105us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3_RFE_100.hdf5
# Test accuracy: 0.8949232585596222
# ...

# %%
for k in range(10,17):
    if(k%3 == 0) :continue
    test_path,model_path = get_data(k,200)
    len_type,X_test,y_test_onehot = deal_data(test_path)
    
    model = load_model(model_path)
    y_pred =  model.predict(X_test,verbose=1)
    
    # 數值評估
    y_len = len(y_pred)
    y_pred_class = np.zeros((y_len,2),dtype=np.int)
    for i in range(0,y_len):
        if (y_pred[i][0] > y_pred[i][1]):
            y_pred_class[i][0] = 1
        else:
            y_pred_class[i][1] = 1
    
    TP=0
    FP=0
    TN=0
    FN=0
    acc=0
    Sen=0
    Pre=0
    
    for i in range(0,y_len):
        if(y_pred_class[i][0] == y_test_onehot[i][0]):
            if(y_pred_class[i][0] == 0):
                TP += 1
            else:
                TN +=1
        else:
            if(y_pred_class[i][0] == 1):
                FP += 1
            else:
                FN +=1
    acc = (TP+TN)/(TP+TN+FP+FN)
    if(TP != 0):Sen = TP/(TP+FN)
    if(TP != 0):Pre = TP/(TP+FP)
    '''
    print(TP)
    print(TN)
    print(FP)
    print(FN)
    print(acc)
    print(Sen)
    print(Pre)
    '''
    print('Model:',model_path)
    print('Test accuracy:', acc)
    
    with open(model_path+'_result.txt',"w") as f:
        f.write('Test accuracy:' + str(acc) + '\n')
        f.write('Test TP:' + str(TP) + '\n')
        f.write('Test FP:' + str(FP) + '\n')
        f.write('Test TN:' + str(TN) + '\n')
        f.write('Test FN:' + str(FN) + '\n')
        f.write('Test Sen:' + str(Sen) + '\n')
        f.write('Test Pre:' + str(Pre) + '\n')
# Out:
# (1694, 100, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 132us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2_RFE_200.hdf5
# Test accuracy: 0.9309327036599764
# (1694, 100, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 105us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3_RFE_200.hdf5
# Test accuracy: 0.9262101534828807
# (1694, 100, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 121us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2_RFE_200.hdf5
# Test accuracy: 0.9203069657615112
# (1694, 100, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 110us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3_RFE_200.hdf5
# Test accuracy: 0.8813459268004723
# ...

# %%
for k in range(10,17):
    if(k%3 == 0) :continue
    test_path,model_path = get_data(k,300)
    len_type,X_test,y_test_onehot = deal_data(test_path)
    
    model = load_model(model_path)
    y_pred =  model.predict(X_test,verbose=1)
    
    # 數值評估
    y_len = len(y_pred)
    y_pred_class = np.zeros((y_len,2),dtype=np.int)
    for i in range(0,y_len):
        if (y_pred[i][0] > y_pred[i][1]):
            y_pred_class[i][0] = 1
        else:
            y_pred_class[i][1] = 1
    
    TP=0
    FP=0
    TN=0
    FN=0
    acc=0
    Sen=0
    Pre=0
    
    for i in range(0,y_len):
        if(y_pred_class[i][0] == y_test_onehot[i][0]):
            if(y_pred_class[i][0] == 0):
                TP += 1
            else:
                TN +=1
        else:
            if(y_pred_class[i][0] == 1):
                FP += 1
            else:
                FN +=1
    acc = (TP+TN)/(TP+TN+FP+FN)
    if(TP != 0):Sen = TP/(TP+FN)
    if(TP != 0):Pre = TP/(TP+FP)
    '''
    print(TP)
    print(TN)
    print(FP)
    print(FN)
    print(acc)
    print(Sen)
    print(Pre)
    '''
    print('Model:',model_path)
    print('Test accuracy:', acc)
    
    with open(model_path+'_result.txt',"w") as f:
        f.write('Test accuracy:' + str(acc) + '\n')
        f.write('Test TP:' + str(TP) + '\n')
        f.write('Test FP:' + str(FP) + '\n')
        f.write('Test TN:' + str(TN) + '\n')
        f.write('Test FN:' + str(FN) + '\n')
        f.write('Test Sen:' + str(Sen) + '\n')
        f.write('Test Pre:' + str(Pre) + '\n')
# Out:
# (1694, 150, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 130us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2_RFE_300.hdf5
# Test accuracy: 0.9344746162927982
# (1694, 150, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 143us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3_RFE_300.hdf5
# Test accuracy: 0.9362455726092089
# (1694, 150, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 118us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2_RFE_300.hdf5
# Test accuracy: 0.8955135773317592
# (1694, 150, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 129us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3_RFE_300.hdf5
# Test accuracy: 0.8907910271546635
# ...

# %%
for k in range(10,17):
    if(k%3 == 0) :continue
    test_path,model_path = get_data(k,400)
    len_type,X_test,y_test_onehot = deal_data(test_path)
    
    model = load_model(model_path)
    y_pred =  model.predict(X_test,verbose=1)
    
    # 數值評估
    y_len = len(y_pred)
    y_pred_class = np.zeros((y_len,2),dtype=np.int)
    for i in range(0,y_len):
        if (y_pred[i][0] > y_pred[i][1]):
            y_pred_class[i][0] = 1
        else:
            y_pred_class[i][1] = 1
    
    TP=0
    FP=0
    TN=0
    FN=0
    acc=0
    Sen=0
    Pre=0
    
    for i in range(0,y_len):
        if(y_pred_class[i][0] == y_test_onehot[i][0]):
            if(y_pred_class[i][0] == 0):
                TP += 1
            else:
                TN +=1
        else:
            if(y_pred_class[i][0] == 1):
                FP += 1
            else:
                FN +=1
    acc = (TP+TN)/(TP+TN+FP+FN)
    if(TP != 0):Sen = TP/(TP+FN)
    if(TP != 0):Pre = TP/(TP+FP)
    '''
    print(TP)
    print(TN)
    print(FP)
    print(FN)
    print(acc)
    print(Sen)
    print(Pre)
    '''
    print('Model:',model_path)
    print('Test accuracy:', acc)
    
    with open(model_path+'_result.txt',"w") as f:
        f.write('Test accuracy:' + str(acc) + '\n')
        f.write('Test TP:' + str(TP) + '\n')
        f.write('Test FP:' + str(FP) + '\n')
        f.write('Test TN:' + str(TN) + '\n')
        f.write('Test FN:' + str(FN) + '\n')
        f.write('Test Sen:' + str(Sen) + '\n')
        f.write('Test Pre:' + str(Pre) + '\n')
# Out:
# (1694, 200, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 142us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2_RFE_400.hdf5
# Test accuracy: 0.9067296340023613
# (1694, 200, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 132us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3_RFE_400.hdf5
# Test accuracy: 0.9574970484061394
# (1694, 200, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 144us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2_RFE_400.hdf5
# Test accuracy: 0.898465171192444
# (1694, 200, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 140us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3_RFE_400.hdf5
# Test accuracy: 0.9073199527744983
# ...

# %%
for k in range(10,17):
    if(k%3 == 0) :continue
    test_path,model_path = get_data(k,500)
    len_type,X_test,y_test_onehot = deal_data(test_path)
    
    model = load_model(model_path)
    y_pred =  model.predict(X_test,verbose=1)
    
    # 數值評估
    y_len = len(y_pred)
    y_pred_class = np.zeros((y_len,2),dtype=np.int)
    for i in range(0,y_len):
        if (y_pred[i][0] > y_pred[i][1]):
            y_pred_class[i][0] = 1
        else:
            y_pred_class[i][1] = 1
    
    TP=0
    FP=0
    TN=0
    FN=0
    acc=0
    Sen=0
    Pre=0
    
    for i in range(0,y_len):
        if(y_pred_class[i][0] == y_test_onehot[i][0]):
            if(y_pred_class[i][0] == 0):
                TP += 1
            else:
                TN +=1
        else:
            if(y_pred_class[i][0] == 1):
                FP += 1
            else:
                FN +=1
    acc = (TP+TN)/(TP+TN+FP+FN)
    if(TP != 0):Sen = TP/(TP+FN)
    if(TP != 0):Pre = TP/(TP+FP)
    '''
    print(TP)
    print(TN)
    print(FP)
    print(FN)
    print(acc)
    print(Sen)
    print(Pre)
    '''
    print('Model:',model_path)
    print('Test accuracy:', acc)
    
    with open(model_path+'_result.txt',"w") as f:
        f.write('Test accuracy:' + str(acc) + '\n')
        f.write('Test TP:' + str(TP) + '\n')
        f.write('Test FP:' + str(FP) + '\n')
        f.write('Test TN:' + str(TN) + '\n')
        f.write('Test FN:' + str(FN) + '\n')
        f.write('Test Sen:' + str(Sen) + '\n')
        f.write('Test Pre:' + str(Pre) + '\n')
# Out:
# (1694, 250, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 144us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2_RFE_500.hdf5
# Test accuracy: 0.9332939787485242
# (1694, 250, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 160us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3_RFE_500.hdf5
# Test accuracy: 0.9456906729634003
# (1694, 250, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 146us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2_RFE_500.hdf5
# Test accuracy: 0.9025974025974026
# (1694, 250, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 0s 146us/step
# Model: ./model/DNN_RFE/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3_RFE_500.hdf5
# Test accuracy: 0.9079102715466352
# ...
