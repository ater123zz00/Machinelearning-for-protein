# %% [markdown]
# #  版本確認
# #PYTHON 3.7
# #tensorflow==2.0.0
# #keras==2.5.4

# %%
import sys
print(sys.version)
print(sys.executable)
import tensorflow as tf
tf.__version__
# Out:
# 3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]
# C:\Users\user\anaconda3\envs\tensorflow_py37\python.exe
# '2.0.0'

# %% [markdown]
# # import 函式庫

# %%
import numpy as np
import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()
import os
from sklearn.model_selection import train_test_split
import random
import keras
from tensorflow.python.framework import ops
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPool2D,MaxPooling2D,GlobalAveragePooling2D,AveragePooling2D,Input, concatenate
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
import itertools
from keras.models import Model,load_model
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import tensorflow.keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # DATA資料讀取

# %%
def get_data(k1_n):
    if k1_n == 1:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1.dat'
    if k1_n == 2:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2.dat'
    if k1_n == 3:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt3.dat'
    if k1_n == 4:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 5:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 6:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 7:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt3.dat'

    if k1_n == 8:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1.dat'
    if k1_n == 9:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2.dat'
    if k1_n == 10:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt3.dat'
    if k1_n == 11:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 12:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 13:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 14:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt3.dat'
    
    if k1_n == 15:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1.dat'
    if k1_n == 16:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2.dat'
    if k1_n == 17:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3.dat'
    if k1_n == 18:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 19:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 20:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 21:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3.dat'
        
    if k1_n == 22:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1.dat'
    if k1_n == 23:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2.dat'
    if k1_n == 24:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt3.dat'
    if k1_n == 25:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 26:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 27:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 28:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3.dat'

    if k1_n == 29:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1.dat'
    if k1_n == 30:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2.dat'
    if k1_n == 31:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt3.dat'
    if k1_n == 32:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 33:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 34:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1_lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 35:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3.dat'
        
    data_path = './272623/data/'
    train_path = data_path+data
    return train_path,ver

# %% [markdown]
# # ONE_HOT 編碼轉換

# %%
def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1

    return one_hot_encode

# %% [markdown]
# # 資料前處理
# 1.data資料分割
# 2.np.array.reshape
# 3.one_hot轉換

# %%
def deal_data(train_path):
    y_train= list()
    X_train= list()
    f = open(train_path,'r')
    s = f.read()
    f.close()
    data_train = s.split("\n")
    data_train.pop()
    random.shuffle(data_train)
    #print(data_train[0])
    for i in data_train:
        data_t = i.split(" ",1)
        y_train.append(data_t[0])
        X_train.append(data_t[1])
        #print(data_t[0])
        #print(data_t[1])
    data_x_train = list()
    for i in range(0,len(X_train)):
        data_t2 = X_train[i].split(" ")
        data_t2.pop()
        #print(len(data_t2))
        data_x_train.append(np.zeros( len(data_t2) ))
        for i_2 in data_t2:
            temp = i_2.split(":")
            temp[0] = int(temp[0])-1
            temp[1] = float(temp[1])
            data_x_train[i][temp[0]] = temp[1]
            #print(type(temp[0]) )
            #print(type(temp[1]) )
    X_train = np.array(data_x_train)
    y_train_label = np.array(y_train)
        
    #X_test = np.array(data_x_test)
    #y_test_label = np.array(y_test)
    
    #print(X_train.shape)
    #print(y_train_label.shape)
    #print(X_test.shape)
    #print(y_test_label.shape)
    
    len_type = int( (len(data_x_train[0]))/2) 

    
    X_train = np.reshape(X_train, [-1,len_type,2,1])
    #X_test = np.reshape(X_test, [-1,2,len_type,len_type])
    #X_test = np.swapaxes(X_test,1,3)
    y_train_onehot = to_categorical(y_train_label)
    #y_test_onehot = to_categorical(y_test_label)
    print(X_train.shape)
    print(y_train_onehot.shape)
    #print(X_test.shape)
    #print(y_test_onehot.shape)
    return len_type,X_train,y_train_onehot

# %% [markdown]
# # Model 建立

# %%
def Conv2d_BN(x, nb_filter,kernel_size, padding='same',strides=(1,1),name=None):
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None

    x = Conv2D(nb_filter,kernel_size,padding=padding,strides=strides,activation='relu',name=conv_name)(x)
    x = BatchNormalization(axis=3,name=bn_name)(x)
    return x

# %%
def Inception(x,nb_filter_para):
    (branch1,branch2,branch3,branch4)= nb_filter_para
    branch1x1 = Conv2D(branch1[0],(1,1), padding='same',strides=(1,1),name=None)(x)

    branch3x3 = Conv2D(branch2[0],(1,1), padding='same',strides=(1,1),name=None)(x)
    branch3x3 = Conv2D(branch2[1],(3,3), padding='same',strides=(1,1),name=None)(branch3x3)

    branch5x5 = Conv2D(branch3[0],(1,1), padding='same',strides=(1,1),name=None)(x)
    branch5x5 = Conv2D(branch3[1],(1,1), padding='same',strides=(1,1),name=None)(branch5x5)

    branchpool = MaxPooling2D(pool_size=(3,3),strides=(1,1),padding='same')(x)
    branchpool = Conv2D(branch4[0],(1,1),padding='same',strides=(1,1),name=None)(branchpool)

    x = concatenate([branch1x1,branch3x3,branch5x5,branchpool],axis=3)

    return x

# %%
def InceptionV1(width, height, depth, classes):
    
    inpt = Input(shape=(width,height,depth))

    x = Conv2d_BN(inpt,64,(7,7),strides=(2,2),padding='same')
    x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
    x = Conv2d_BN(x,192,(3,3),strides=(1,1),padding='same')
    x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)

    x = Inception(x,[(64,),(96,128),(16,32),(32,)]) #Inception 3a 28x28x256
    x = Inception(x,[(128,),(128,192),(32,96),(64,)]) #Inception 3b 28x28x480
    x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x) #14x14x480

    x = Inception(x,[(192,),(96,208),(16,48),(64,)]) #Inception 4a 14x14x512
    x = Inception(x,[(160,),(112,224),(24,64),(64,)]) #Inception 4a 14x14x512
    x = Inception(x,[(128,),(128,256),(24,64),(64,)]) #Inception 4a 14x14x512
    x = Inception(x,[(112,),(144,288),(32,64),(64,)]) #Inception 4a 14x14x528
    x = Inception(x,[(256,),(160,320),(32,128),(128,)]) #Inception 4a 14x14x832
    x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x) #7x7x832

    x = Inception(x,[(256,),(160,320),(32,128),(128,)]) #Inception 5a 7x7x832
    x = Inception(x,[(384,),(192,384),(48,128),(128,)]) #Inception 5b 7x7x1024

    #Using AveragePooling replace flatten
    x = AveragePooling2D(pool_size=(7,7),strides=(7,7),padding='same')(x)
    x =Flatten()(x)
    x = Dropout(0.4)(x)
    x = Dense(1000,activation='relu')(x)
    x = Dense(classes,activation='softmax')(x)
    
    model=Model(input=inpt,output=x)
    
    return model

# %%
batch_size = 100
epochs = 1000
num_classes = 2
weight_decay = 1e-5
patience = [20]
for p in patience:
    for k in range(15,36):
        train_path,ver = get_data(k)
        len_type,X_train,y_train_onehot = deal_data(train_path)
        model_path = './model/GoogLeNet_lt/'+ver+'p='+str(p)+'.hdf5'
        
        InceptionV1_model = InceptionV1(len_type,2,1,2)
        #InceptionV1_model.summary()
        InceptionV1_model.compile(optimizer=Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08),loss = 'categorical_crossentropy',metrics=['accuracy'])
    
        es=EarlyStopping(
            monitor='val_accuracy',
            patience=p,
            verbose=0,
            restore_best_weights=True
        )
        mc=ModelCheckpoint(
            model_path,
            monitor='val_accuracy',
            verbose=1,
            save_best_only=True,
            save_weights_only=False,
            mode='max',
            period=1
        )
        
    
        history = InceptionV1_model.fit(
            X_train,
            y_train_onehot,
            batch_size=batch_size,
            epochs = epochs,
            callbacks=[es,mc],
            validation_split = 0.1,
            verbose=1
        )
        
        with open(model_path+'_train_log.txt',"w") as f:
            f.write('Patience:' + str(p) + '\n')
            f.write('Train accuracy:' + str(max(history.history['accuracy']) ) + '\n')
            f.write('Val accuracy:' + str(max(history.history['val_accuracy']) ) + '\n')
# Out:
# (6462, 100, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 15s 3ms/step - loss: 0.8402 - accuracy: 0.4889 - val_loss: 0.6930 - val_accuracy: 0.5100
#
# Epoch 00001: val_accuracy improved from -inf to 0.51005, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7161 - accuracy: 0.4987 - val_loss: 0.6929 - val_accuracy: 0.5100
#
# Epoch 00002: val_accuracy did not improve from 0.51005
# Epoch 3/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7123 - accuracy: 0.5040 - val_loss: 0.6932 - val_accuracy: 0.4900
#
# Epoch 00003: val_accuracy did not improve from 0.51005
# Epoch 4/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7156 - accuracy: 0.4965 - val_loss: 0.6931 - val_accuracy: 0.5054
#
# Epoch 00004: val_accuracy did not improve from 0.51005
# Epoch 5/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7130 - accuracy: 0.4999 - val_loss: 0.6929 - val_accuracy: 0.5100
#
# Epoch 00005: val_accuracy did not improve from 0.51005
# Epoch 6/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7134 - accuracy: 0.5137 - val_loss: 0.6942 - val_accuracy: 0.5100
#
# Epoch 00006: val_accuracy did not improve from 0.51005
# Epoch 7/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7110 - accuracy: 0.4968 - val_loss: 0.6943 - val_accuracy: 0.5100
#
# Epoch 00007: val_accuracy did not improve from 0.51005
# Epoch 8/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7063 - accuracy: 0.5080 - val_loss: 0.6951 - val_accuracy: 0.5100
#
# Epoch 00008: val_accuracy did not improve from 0.51005
# Epoch 9/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7063 - accuracy: 0.5025 - val_loss: 0.6955 - val_accuracy: 0.5100
#
# Epoch 00009: val_accuracy did not improve from 0.51005
# Epoch 10/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7058 - accuracy: 0.5111 - val_loss: 0.6953 - val_accuracy: 0.4930
#
# Epoch 00010: val_accuracy did not improve from 0.51005
# Epoch 11/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7068 - accuracy: 0.5001 - val_loss: 0.7133 - val_accuracy: 0.4900
#
# Epoch 00011: val_accuracy did not improve from 0.51005
# Epoch 12/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7093 - accuracy: 0.4729 - val_loss: 0.6998 - val_accuracy: 0.4266
#
# Epoch 00012: val_accuracy did not improve from 0.51005
# Epoch 13/1000
# 5815/5815 [==============================] - 14s 2ms/step - loss: 0.7028 - accuracy: 0.5016 - val_loss: 0.7005 - val_accuracy: 0.5023
#
# Epoch 00013: val_accuracy did not improve from 0.51005
# Epoch 14/1000
# 5815/5815 [==============================] - 14s 2ms/step - loss: 0.7029 - accuracy: 0.4968 - val_loss: 0.6989 - val_accuracy: 0.4606
#
# Epoch 00014: val_accuracy did not improve from 0.51005
# Epoch 15/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7019 - accuracy: 0.4953 - val_loss: 0.7077 - val_accuracy: 0.5100
#
# Epoch 00015: val_accuracy did not improve from 0.51005
# Epoch 16/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7016 - accuracy: 0.4877 - val_loss: 0.7154 - val_accuracy: 0.4900
#
# Epoch 00016: val_accuracy did not improve from 0.51005
# Epoch 17/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7040 - accuracy: 0.4961 - val_loss: 0.7036 - val_accuracy: 0.5100
#
# Epoch 00017: val_accuracy did not improve from 0.51005
# Epoch 18/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7037 - accuracy: 0.4910 - val_loss: 0.6977 - val_accuracy: 0.4575
#
# Epoch 00018: val_accuracy did not improve from 0.51005
# Epoch 19/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7003 - accuracy: 0.4936 - val_loss: 0.6987 - val_accuracy: 0.4683
#
# Epoch 00019: val_accuracy did not improve from 0.51005
# Epoch 20/1000
# 5815/5815 [==============================] - 13s 2ms/step - loss: 0.7001 - accuracy: 0.5035 - val_loss: 0.6985 - val_accuracy: 0.4822
#
# Epoch 00020: val_accuracy did not improve from 0.51005
# Epoch 21/1000
# 5815/5815 [==============================] - 14s 2ms/step - loss: 0.7014 - accuracy: 0.4980 - val_loss: 0.7071 - val_accuracy: 0.5070
#
# Epoch 00021: val_accuracy did not improve from 0.51005
# (6462, 988, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 122s 21ms/step - loss: 0.7284 - accuracy: 0.5806 - val_loss: 0.6928 - val_accuracy: 0.5054
#
# Epoch 00001: val_accuracy improved from -inf to 0.50541, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 0.5004 - accuracy: 0.7556 - val_loss: 0.6918 - val_accuracy: 0.5054
#
# Epoch 00002: val_accuracy did not improve from 0.50541
# Epoch 3/1000
# 5815/5815 [==============================] - 116s 20ms/step - loss: 0.3211 - accuracy: 0.8554 - val_loss: 0.6879 - val_accuracy: 0.5054
#
# Epoch 00003: val_accuracy did not improve from 0.50541
# Epoch 4/1000
# 5815/5815 [==============================] - 119s 21ms/step - loss: 0.2396 - accuracy: 0.8991 - val_loss: 0.6793 - val_accuracy: 0.5070
#
# Epoch 00004: val_accuracy improved from 0.50541 to 0.50696, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 5/1000
# 5815/5815 [==============================] - 114s 20ms/step - loss: 0.1617 - accuracy: 0.9365 - val_loss: 0.6551 - val_accuracy: 0.5951
#
# Epoch 00005: val_accuracy improved from 0.50696 to 0.59505, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 6/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 0.1409 - accuracy: 0.9439 - val_loss: 0.6151 - val_accuracy: 0.9165
#
# Epoch 00006: val_accuracy improved from 0.59505 to 0.91654, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 7/1000
# 5815/5815 [==============================] - 114s 20ms/step - loss: 0.0839 - accuracy: 0.9687 - val_loss: 0.5210 - val_accuracy: 0.9088
#
# Epoch 00007: val_accuracy did not improve from 0.91654
# Epoch 8/1000
# 5815/5815 [==============================] - 117s 20ms/step - loss: 0.0805 - accuracy: 0.9715 - val_loss: 0.3900 - val_accuracy: 0.9645
#
# Epoch 00008: val_accuracy improved from 0.91654 to 0.96445, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 9/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 0.0801 - accuracy: 0.9706 - val_loss: 0.2829 - val_accuracy: 0.9645
#
# Epoch 00009: val_accuracy did not improve from 0.96445
# Epoch 10/1000
# 5815/5815 [==============================] - 113s 19ms/step - loss: 0.0527 - accuracy: 0.9838 - val_loss: 0.1773 - val_accuracy: 0.9490
#
# Epoch 00010: val_accuracy did not improve from 0.96445
# Epoch 11/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 0.0363 - accuracy: 0.9873 - val_loss: 0.1503 - val_accuracy: 0.9413
#
# Epoch 00011: val_accuracy did not improve from 0.96445
# Epoch 12/1000
# 5815/5815 [==============================] - 113s 19ms/step - loss: 0.0580 - accuracy: 0.9766 - val_loss: 0.1049 - val_accuracy: 0.9629
#
# Epoch 00012: val_accuracy did not improve from 0.96445
# Epoch 13/1000
# 5815/5815 [==============================] - 117s 20ms/step - loss: 0.0271 - accuracy: 0.9917 - val_loss: 0.1265 - val_accuracy: 0.9660
#
# Epoch 00013: val_accuracy improved from 0.96445 to 0.96600, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 14/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 0.0374 - accuracy: 0.9864 - val_loss: 0.2012 - val_accuracy: 0.9459
#
# Epoch 00014: val_accuracy did not improve from 0.96600
# Epoch 15/1000
# 5815/5815 [==============================] - 113s 20ms/step - loss: 0.0364 - accuracy: 0.9869 - val_loss: 0.1294 - val_accuracy: 0.9706
#
# Epoch 00015: val_accuracy improved from 0.96600 to 0.97063, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 16/1000
# 5815/5815 [==============================] - 119s 20ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.1123 - val_accuracy: 0.9691
#
# Epoch 00016: val_accuracy did not improve from 0.97063
# Epoch 17/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.1415 - val_accuracy: 0.9706
#
# Epoch 00017: val_accuracy did not improve from 0.97063
# Epoch 18/1000
# 5815/5815 [==============================] - 122s 21ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1976 - val_accuracy: 0.9645
#
# Epoch 00018: val_accuracy did not improve from 0.97063
# Epoch 19/1000
# 5815/5815 [==============================] - 117s 20ms/step - loss: 7.2773e-04 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.9706
#
# Epoch 00019: val_accuracy did not improve from 0.97063
# Epoch 20/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 5.8007e-04 - accuracy: 0.9998 - val_loss: 0.1524 - val_accuracy: 0.9691
#
# Epoch 00020: val_accuracy did not improve from 0.97063
# Epoch 21/1000
# 5815/5815 [==============================] - 119s 20ms/step - loss: 6.8891e-04 - accuracy: 0.9998 - val_loss: 0.1479 - val_accuracy: 0.9706
#
# Epoch 00021: val_accuracy did not improve from 0.97063
# Epoch 22/1000
# 5815/5815 [==============================] - 116s 20ms/step - loss: 6.2395e-05 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.9737
#
# Epoch 00022: val_accuracy improved from 0.97063 to 0.97372, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2p=20.hdf5
# Epoch 23/1000
# 5815/5815 [==============================] - 121s 21ms/step - loss: 4.0715e-05 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9737
#
# Epoch 00023: val_accuracy did not improve from 0.97372
# Epoch 24/1000
# 5815/5815 [==============================] - 121s 21ms/step - loss: 3.2400e-05 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9737
#
# Epoch 00024: val_accuracy did not improve from 0.97372
# Epoch 25/1000
# 5815/5815 [==============================] - 121s 21ms/step - loss: 2.5676e-05 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9737
#
# Epoch 00025: val_accuracy did not improve from 0.97372
# Epoch 26/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 2.1607e-05 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 0.9737
#
# Epoch 00026: val_accuracy did not improve from 0.97372
# Epoch 27/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 2.0689e-05 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9737
#
# Epoch 00027: val_accuracy did not improve from 0.97372
# Epoch 28/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 1.8955e-05 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9737
#
# Epoch 00028: val_accuracy did not improve from 0.97372
# Epoch 29/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 1.7070e-05 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9737
#
# Epoch 00029: val_accuracy did not improve from 0.97372
# Epoch 30/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 1.5159e-05 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9737
#
# Epoch 00030: val_accuracy did not improve from 0.97372
# Epoch 31/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 1.4700e-05 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9737
#
# Epoch 00031: val_accuracy did not improve from 0.97372
# Epoch 32/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 1.2452e-05 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9722
#
# Epoch 00032: val_accuracy did not improve from 0.97372
# Epoch 33/1000
# 5815/5815 [==============================] - 119s 20ms/step - loss: 1.3106e-05 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9722
#
# Epoch 00033: val_accuracy did not improve from 0.97372
# Epoch 34/1000
# 5815/5815 [==============================] - 121s 21ms/step - loss: 1.2156e-05 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9722
#
# Epoch 00034: val_accuracy did not improve from 0.97372
# Epoch 35/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 9.7698e-06 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9722
#
# Epoch 00035: val_accuracy did not improve from 0.97372
# Epoch 36/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 8.6008e-06 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9722
#
# Epoch 00036: val_accuracy did not improve from 0.97372
# Epoch 37/1000
# 5815/5815 [==============================] - 119s 21ms/step - loss: 9.9419e-06 - accuracy: 1.0000 - val_loss: 0.1708 - val_accuracy: 0.9737
#
# Epoch 00037: val_accuracy did not improve from 0.97372
# Epoch 38/1000
# 5815/5815 [==============================] - 120s 21ms/step - loss: 8.5841e-06 - accuracy: 1.0000 - val_loss: 0.1705 - val_accuracy: 0.9722
#
# Epoch 00038: val_accuracy did not improve from 0.97372
# Epoch 39/1000
# 5815/5815 [==============================] - 119s 20ms/step - loss: 7.8798e-06 - accuracy: 1.0000 - val_loss: 0.1713 - val_accuracy: 0.9722
#
# Epoch 00039: val_accuracy did not improve from 0.97372
# Epoch 40/1000
# 5815/5815 [==============================] - 121s 21ms/step - loss: 7.0917e-06 - accuracy: 1.0000 - val_loss: 0.1718 - val_accuracy: 0.9722
#
# Epoch 00040: val_accuracy did not improve from 0.97372
# Epoch 41/1000
# 5815/5815 [==============================] - 119s 20ms/step - loss: 6.9268e-06 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9737
#
# Epoch 00041: val_accuracy did not improve from 0.97372
# Epoch 42/1000
# 5815/5815 [==============================] - 118s 20ms/step - loss: 6.8210e-06 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9737
#
# Epoch 00042: val_accuracy did not improve from 0.97372
# (6462, 3001, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 537s 92ms/step - loss: 0.7542 - accuracy: 0.5751 - val_loss: 0.6972 - val_accuracy: 0.4776
#
# Epoch 00001: val_accuracy improved from -inf to 0.47759, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 534s 92ms/step - loss: 0.4073 - accuracy: 0.8167 - val_loss: 0.6969 - val_accuracy: 0.4776
#
# Epoch 00002: val_accuracy did not improve from 0.47759
# Epoch 3/1000
# 5815/5815 [==============================] - 535s 92ms/step - loss: 0.1979 - accuracy: 0.9245 - val_loss: 0.6967 - val_accuracy: 0.4776
#
# Epoch 00003: val_accuracy did not improve from 0.47759
# Epoch 4/1000
# 5815/5815 [==============================] - 533s 92ms/step - loss: 0.1210 - accuracy: 0.9551 - val_loss: 0.6795 - val_accuracy: 0.4822
#
# Epoch 00004: val_accuracy improved from 0.47759 to 0.48223, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 5/1000
# 5815/5815 [==============================] - 533s 92ms/step - loss: 0.1118 - accuracy: 0.9620 - val_loss: 0.6654 - val_accuracy: 0.4838
#
# Epoch 00005: val_accuracy improved from 0.48223 to 0.48377, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 6/1000
# 5815/5815 [==============================] - 533s 92ms/step - loss: 0.0457 - accuracy: 0.9831 - val_loss: 0.6012 - val_accuracy: 0.7821
#
# Epoch 00006: val_accuracy improved from 0.48377 to 0.78207, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 7/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 0.0278 - accuracy: 0.9919 - val_loss: 0.4978 - val_accuracy: 0.8640
#
# Epoch 00007: val_accuracy improved from 0.78207 to 0.86399, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 8/1000
# 5815/5815 [==============================] - 537s 92ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.4135 - val_accuracy: 0.7805
#
# Epoch 00008: val_accuracy did not improve from 0.86399
# Epoch 9/1000
# 5815/5815 [==============================] - 538s 92ms/step - loss: 0.0533 - accuracy: 0.9814 - val_loss: 0.2176 - val_accuracy: 0.9799
#
# Epoch 00009: val_accuracy improved from 0.86399 to 0.97991, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 10/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.1046 - val_accuracy: 0.9768
#
# Epoch 00010: val_accuracy did not improve from 0.97991
# Epoch 11/1000
# 5815/5815 [==============================] - 533s 92ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0814 - val_accuracy: 0.9799
#
# Epoch 00011: val_accuracy did not improve from 0.97991
# Epoch 12/1000
# 5815/5815 [==============================] - 535s 92ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0665 - val_accuracy: 0.9784
#
# Epoch 00012: val_accuracy did not improve from 0.97991
# Epoch 13/1000
# 5815/5815 [==============================] - 534s 92ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0674 - val_accuracy: 0.9784
#
# Epoch 00013: val_accuracy did not improve from 0.97991
# Epoch 14/1000
# 5815/5815 [==============================] - 537s 92ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0803 - val_accuracy: 0.9799
#
# Epoch 00014: val_accuracy did not improve from 0.97991
# Epoch 15/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.1415 - val_accuracy: 0.9753
#
# Epoch 00015: val_accuracy did not improve from 0.97991
# Epoch 16/1000
# 5815/5815 [==============================] - 538s 93ms/step - loss: 0.0273 - accuracy: 0.9912 - val_loss: 0.0576 - val_accuracy: 0.9892
#
# Epoch 00016: val_accuracy improved from 0.97991 to 0.98918, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3p=20.hdf5
# Epoch 17/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 0.2143 - accuracy: 0.9393 - val_loss: 0.2762 - val_accuracy: 0.9042
#
# Epoch 00017: val_accuracy did not improve from 0.98918
# Epoch 18/1000
# 5815/5815 [==============================] - 534s 92ms/step - loss: 0.0220 - accuracy: 0.9931 - val_loss: 0.0627 - val_accuracy: 0.9799
#
# Epoch 00018: val_accuracy did not improve from 0.98918
# Epoch 19/1000
# 5815/5815 [==============================] - 531s 91ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0615 - val_accuracy: 0.9815
#
# Epoch 00019: val_accuracy did not improve from 0.98918
# Epoch 20/1000
# 5815/5815 [==============================] - 534s 92ms/step - loss: 6.1354e-04 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9815
#
# Epoch 00020: val_accuracy did not improve from 0.98918
# Epoch 21/1000
# 5815/5815 [==============================] - 535s 92ms/step - loss: 4.2023e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9815
#
# Epoch 00021: val_accuracy did not improve from 0.98918
# Epoch 22/1000
# 5815/5815 [==============================] - 538s 93ms/step - loss: 2.4711e-04 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 0.9815
#
# Epoch 00022: val_accuracy did not improve from 0.98918
# Epoch 23/1000
# 5815/5815 [==============================] - 534s 92ms/step - loss: 2.0145e-04 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9815
#
# Epoch 00023: val_accuracy did not improve from 0.98918
# Epoch 24/1000
# 5815/5815 [==============================] - 537s 92ms/step - loss: 1.4285e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9815
#
# Epoch 00024: val_accuracy did not improve from 0.98918
# Epoch 25/1000
# 5815/5815 [==============================] - 537s 92ms/step - loss: 1.3726e-04 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9799
#
# Epoch 00025: val_accuracy did not improve from 0.98918
# Epoch 26/1000
# 5815/5815 [==============================] - 538s 92ms/step - loss: 1.0979e-04 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9815
#
# Epoch 00026: val_accuracy did not improve from 0.98918
# Epoch 27/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 1.0763e-04 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9799
#
# Epoch 00027: val_accuracy did not improve from 0.98918
# Epoch 28/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 8.6780e-05 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9799
#
# Epoch 00028: val_accuracy did not improve from 0.98918
# Epoch 29/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 8.1261e-05 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9799
#
# Epoch 00029: val_accuracy did not improve from 0.98918
# Epoch 30/1000
# 5815/5815 [==============================] - 537s 92ms/step - loss: 6.9048e-05 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9815
#
# Epoch 00030: val_accuracy did not improve from 0.98918
# Epoch 31/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 5.8888e-05 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9815
#
# Epoch 00031: val_accuracy did not improve from 0.98918
# Epoch 32/1000
# 5815/5815 [==============================] - 539s 93ms/step - loss: 5.0879e-05 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9815
#
# Epoch 00032: val_accuracy did not improve from 0.98918
# Epoch 33/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 4.9186e-05 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9815
#
# Epoch 00033: val_accuracy did not improve from 0.98918
# Epoch 34/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 4.2815e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9799
#
# Epoch 00034: val_accuracy did not improve from 0.98918
# Epoch 35/1000
# 5815/5815 [==============================] - 536s 92ms/step - loss: 3.9959e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9815
#
# Epoch 00035: val_accuracy did not improve from 0.98918
# Epoch 36/1000
# 5815/5815 [==============================] - 534s 92ms/step - loss: 3.6396e-05 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9799
#
# Epoch 00036: val_accuracy did not improve from 0.98918
# (6462, 1088, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 224s 39ms/step - loss: 0.7992 - accuracy: 0.5281 - val_loss: 0.6931 - val_accuracy: 0.5085
#
# Epoch 00001: val_accuracy improved from -inf to 0.50850, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.5389 - accuracy: 0.7218 - val_loss: 0.6915 - val_accuracy: 0.6832
#
# Epoch 00002: val_accuracy improved from 0.50850 to 0.68315, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 3/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.3234 - accuracy: 0.8542 - val_loss: 0.6875 - val_accuracy: 0.6538
#
# Epoch 00003: val_accuracy did not improve from 0.68315
# Epoch 4/1000
# 5815/5815 [==============================] - 222s 38ms/step - loss: 0.1803 - accuracy: 0.9298 - val_loss: 0.7046 - val_accuracy: 0.4884
#
# Epoch 00004: val_accuracy did not improve from 0.68315
# Epoch 5/1000
# 5815/5815 [==============================] - 222s 38ms/step - loss: 0.1390 - accuracy: 0.9451 - val_loss: 0.6591 - val_accuracy: 0.5951
#
# Epoch 00005: val_accuracy did not improve from 0.68315
# Epoch 6/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.1379 - accuracy: 0.9445 - val_loss: 0.6425 - val_accuracy: 0.5131
#
# Epoch 00006: val_accuracy did not improve from 0.68315
# Epoch 7/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0705 - accuracy: 0.9735 - val_loss: 0.6190 - val_accuracy: 0.5301
#
# Epoch 00007: val_accuracy did not improve from 0.68315
# Epoch 8/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0921 - accuracy: 0.9685 - val_loss: 0.6462 - val_accuracy: 0.5301
#
# Epoch 00008: val_accuracy did not improve from 0.68315
# Epoch 9/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0330 - accuracy: 0.9880 - val_loss: 0.4921 - val_accuracy: 0.6909
#
# Epoch 00009: val_accuracy improved from 0.68315 to 0.69088, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 10/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0529 - accuracy: 0.9795 - val_loss: 0.3688 - val_accuracy: 0.8053
#
# Epoch 00010: val_accuracy improved from 0.69088 to 0.80525, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 11/1000
# 5815/5815 [==============================] - 223s 38ms/step - loss: 0.0241 - accuracy: 0.9923 - val_loss: 0.1155 - val_accuracy: 0.9614
#
# Epoch 00011: val_accuracy improved from 0.80525 to 0.96136, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 12/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 0.1909 - val_accuracy: 0.9258
#
# Epoch 00012: val_accuracy did not improve from 0.96136
# Epoch 13/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0732 - accuracy: 0.9759 - val_loss: 0.1394 - val_accuracy: 0.9413
#
# Epoch 00013: val_accuracy did not improve from 0.96136
# Epoch 14/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0304 - accuracy: 0.9897 - val_loss: 0.0987 - val_accuracy: 0.9737
#
# Epoch 00014: val_accuracy improved from 0.96136 to 0.97372, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 15/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0364 - accuracy: 0.9862 - val_loss: 0.1399 - val_accuracy: 0.9614
#
# Epoch 00015: val_accuracy did not improve from 0.97372
# Epoch 16/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0873 - val_accuracy: 0.9784
#
# Epoch 00016: val_accuracy improved from 0.97372 to 0.97836, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 17/1000
# 5815/5815 [==============================] - 222s 38ms/step - loss: 0.0151 - accuracy: 0.9933 - val_loss: 0.2663 - val_accuracy: 0.9366
#
# Epoch 00017: val_accuracy did not improve from 0.97836
# Epoch 18/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.3874 - val_accuracy: 0.9057
#
# Epoch 00018: val_accuracy did not improve from 0.97836
# Epoch 19/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0830 - accuracy: 0.9684 - val_loss: 0.1242 - val_accuracy: 0.9675
#
# Epoch 00019: val_accuracy did not improve from 0.97836
# Epoch 20/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0447 - accuracy: 0.9850 - val_loss: 0.1242 - val_accuracy: 0.9536
#
# Epoch 00020: val_accuracy did not improve from 0.97836
# Epoch 21/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 0.0534 - accuracy: 0.9806 - val_loss: 0.0865 - val_accuracy: 0.9722
#
# Epoch 00021: val_accuracy did not improve from 0.97836
# Epoch 22/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0294 - accuracy: 0.9902 - val_loss: 0.0699 - val_accuracy: 0.9784
#
# Epoch 00022: val_accuracy did not improve from 0.97836
# Epoch 23/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0835 - val_accuracy: 0.9799
#
# Epoch 00023: val_accuracy improved from 0.97836 to 0.97991, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 24/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 5.6737e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9830
#
# Epoch 00024: val_accuracy improved from 0.97991 to 0.98300, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2p=20.hdf5
# Epoch 25/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 1.5077e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9830
#
# Epoch 00025: val_accuracy did not improve from 0.98300
# Epoch 26/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 8.5147e-05 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9830
#
# Epoch 00026: val_accuracy did not improve from 0.98300
# Epoch 27/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 7.3700e-05 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9830
#
# Epoch 00027: val_accuracy did not improve from 0.98300
# Epoch 28/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 6.0007e-05 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 0.9830
#
# Epoch 00028: val_accuracy did not improve from 0.98300
# Epoch 29/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 5.4346e-05 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9830
#
# Epoch 00029: val_accuracy did not improve from 0.98300
# Epoch 30/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 4.5999e-05 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9830
#
# Epoch 00030: val_accuracy did not improve from 0.98300
# Epoch 31/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 3.7801e-05 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9830
#
# Epoch 00031: val_accuracy did not improve from 0.98300
# Epoch 32/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 3.4574e-05 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9830
#
# Epoch 00032: val_accuracy did not improve from 0.98300
# Epoch 33/1000
# 5815/5815 [==============================] - 221s 38ms/step - loss: 3.0492e-05 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9830
#
# Epoch 00033: val_accuracy did not improve from 0.98300
# Epoch 34/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 2.7202e-05 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9830
# Epoch 00034: val_accuracy did not improve from 0.98300
# Epoch 35/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 2.4357e-05 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9830
#
# Epoch 00035: val_accuracy did not improve from 0.98300
# Epoch 36/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 2.3036e-05 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9830
#
# Epoch 00036: val_accuracy did not improve from 0.98300
# Epoch 37/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 2.1936e-05 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9830
#
# Epoch 00037: val_accuracy did not improve from 0.98300
# Epoch 38/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 1.8818e-05 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9830
#
# Epoch 00038: val_accuracy did not improve from 0.98300
# Epoch 39/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 1.7066e-05 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9830
#
# Epoch 00039: val_accuracy did not improve from 0.98300
# Epoch 40/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 1.4981e-05 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9830
#
# Epoch 00040: val_accuracy did not improve from 0.98300
# Epoch 41/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 1.6390e-05 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 0.9830
#
# Epoch 00041: val_accuracy did not improve from 0.98300
# Epoch 42/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 1.2951e-05 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9830
#
# Epoch 00042: val_accuracy did not improve from 0.98300
# Epoch 43/1000
# 5815/5815 [==============================] - 219s 38ms/step - loss: 1.1986e-05 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9830
#
# Epoch 00043: val_accuracy did not improve from 0.98300
# Epoch 44/1000
# 5815/5815 [==============================] - 220s 38ms/step - loss: 1.2195e-05 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9830
#
# Epoch 00044: val_accuracy did not improve from 0.98300
# (6462, 3989, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 847s 146ms/step - loss: 0.7961 - accuracy: 0.5431 - val_loss: 0.6945 - val_accuracy: 0.4977
#
# Epoch 00001: val_accuracy improved from -inf to 0.49768, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 840s 145ms/step - loss: 0.4396 - accuracy: 0.8083 - val_loss: 0.6935 - val_accuracy: 0.4977
#
# Epoch 00002: val_accuracy did not improve from 0.49768
# Epoch 3/1000
# 5815/5815 [==============================] - 840s 145ms/step - loss: 0.1876 - accuracy: 0.9247 - val_loss: 0.6984 - val_accuracy: 0.4977
#
# Epoch 00003: val_accuracy did not improve from 0.49768
# Epoch 4/1000
# 5815/5815 [==============================] - 840s 144ms/step - loss: 0.0974 - accuracy: 0.9641 - val_loss: 0.6778 - val_accuracy: 0.4977
#
# Epoch 00004: val_accuracy did not improve from 0.49768
# Epoch 5/1000
# 5815/5815 [==============================] - 839s 144ms/step - loss: 0.1053 - accuracy: 0.9604 - val_loss: 0.6379 - val_accuracy: 0.9320
#
# Epoch 00005: val_accuracy improved from 0.49768 to 0.93199, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 6/1000
# 5815/5815 [==============================] - 841s 145ms/step - loss: 0.0530 - accuracy: 0.9807 - val_loss: 0.5689 - val_accuracy: 0.7481
#
# Epoch 00006: val_accuracy did not improve from 0.93199
# Epoch 7/1000
# 5815/5815 [==============================] - 843s 145ms/step - loss: 0.0435 - accuracy: 0.9850 - val_loss: 0.4923 - val_accuracy: 0.7805
#
# Epoch 00007: val_accuracy did not improve from 0.93199
# Epoch 8/1000
# 5815/5815 [==============================] - 843s 145ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 0.3416 - val_accuracy: 0.8980
#
# Epoch 00008: val_accuracy did not improve from 0.93199
# Epoch 9/1000
# 5815/5815 [==============================] - 844s 145ms/step - loss: 0.0214 - accuracy: 0.9924 - val_loss: 0.2315 - val_accuracy: 0.9335
#
# Epoch 00009: val_accuracy improved from 0.93199 to 0.93354, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 10/1000
# 5815/5815 [==============================] - 838s 144ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.0938 - val_accuracy: 0.9861
#
# Epoch 00010: val_accuracy improved from 0.93354 to 0.98609, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 11/1000
# 5815/5815 [==============================] - 840s 144ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0831 - val_accuracy: 0.9815
#
# Epoch 00011: val_accuracy did not improve from 0.98609
# Epoch 12/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0908 - val_accuracy: 0.9768
#
# Epoch 00012: val_accuracy did not improve from 0.98609
# Epoch 13/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0765 - val_accuracy: 0.9861
#
# Epoch 00013: val_accuracy did not improve from 0.98609
# Epoch 14/1000
# 5815/5815 [==============================] - 840s 144ms/step - loss: 0.0307 - accuracy: 0.9899 - val_loss: 0.4312 - val_accuracy: 0.8764
#
# Epoch 00014: val_accuracy did not improve from 0.98609
# Epoch 15/1000
# 5815/5815 [==============================] - 841s 145ms/step - loss: 0.1459 - accuracy: 0.9522 - val_loss: 0.0828 - val_accuracy: 0.9815
#
# Epoch 00015: val_accuracy did not improve from 0.98609
# Epoch 16/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0820 - val_accuracy: 0.9815
#
# Epoch 00016: val_accuracy did not improve from 0.98609
# Epoch 17/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 0.0116 - accuracy: 0.9952 - val_loss: 0.1156 - val_accuracy: 0.9815
#
# Epoch 00017: val_accuracy did not improve from 0.98609
# Epoch 18/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0951 - val_accuracy: 0.9845
#
# Epoch 00018: val_accuracy did not improve from 0.98609
# Epoch 19/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 0.0174 - accuracy: 0.9936 - val_loss: 0.1171 - val_accuracy: 0.9784
#
# Epoch 00019: val_accuracy did not improve from 0.98609
# Epoch 20/1000
# 5815/5815 [==============================] - 840s 145ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1258 - val_accuracy: 0.9799
#
# Epoch 00020: val_accuracy did not improve from 0.98609
# Epoch 21/1000
# 5815/5815 [==============================] - 841s 145ms/step - loss: 1.2102e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9815
#
# Epoch 00021: val_accuracy did not improve from 0.98609
# Epoch 22/1000
# 5815/5815 [==============================] - 841s 145ms/step - loss: 7.8748e-05 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9815
#
# Epoch 00022: val_accuracy did not improve from 0.98609
# Epoch 23/1000
# 5815/5815 [==============================] - 840s 144ms/step - loss: 5.0314e-05 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9815
#
# Epoch 00023: val_accuracy did not improve from 0.98609
# Epoch 24/1000
# 5815/5815 [==============================] - 843s 145ms/step - loss: 4.7940e-05 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9815
#
# Epoch 00024: val_accuracy did not improve from 0.98609
# Epoch 25/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 3.9392e-05 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9815
#
# Epoch 00025: val_accuracy did not improve from 0.98609
# Epoch 26/1000
# 5815/5815 [==============================] - 844s 145ms/step - loss: 3.2442e-05 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9815
#
# Epoch 00026: val_accuracy did not improve from 0.98609
# Epoch 27/1000
# 5815/5815 [==============================] - 843s 145ms/step - loss: 2.7090e-05 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9815
#
# Epoch 00027: val_accuracy did not improve from 0.98609
# Epoch 28/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 2.4975e-05 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9815
#
# Epoch 00028: val_accuracy did not improve from 0.98609
# Epoch 29/1000
# 5815/5815 [==============================] - 843s 145ms/step - loss: 2.2844e-05 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9815
#
# Epoch 00029: val_accuracy did not improve from 0.98609
# Epoch 30/1000
# 5815/5815 [==============================] - 842s 145ms/step - loss: 1.8925e-05 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9815
#
# Epoch 00030: val_accuracy did not improve from 0.98609
# (6462, 3101, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 909s 156ms/step - loss: 0.8197 - accuracy: 0.5467 - val_loss: 0.6948 - val_accuracy: 0.4915
#
# Epoch 00001: val_accuracy improved from -inf to 0.49150, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 898s 154ms/step - loss: 0.5018 - accuracy: 0.7539 - val_loss: 0.6944 - val_accuracy: 0.4915
#
# Epoch 00002: val_accuracy did not improve from 0.49150
# Epoch 3/1000
# 5815/5815 [==============================] - 899s 155ms/step - loss: 0.2331 - accuracy: 0.9097 - val_loss: 0.6938 - val_accuracy: 0.4915
#
# Epoch 00003: val_accuracy did not improve from 0.49150
# Epoch 4/1000
# 5815/5815 [==============================] - 900s 155ms/step - loss: 0.1395 - accuracy: 0.9463 - val_loss: 0.6770 - val_accuracy: 0.5456
#
# Epoch 00004: val_accuracy improved from 0.49150 to 0.54560, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 5/1000
# 5815/5815 [==============================] - 904s 155ms/step - loss: 0.0806 - accuracy: 0.9701 - val_loss: 0.6733 - val_accuracy: 0.4915
#
# Epoch 00005: val_accuracy did not improve from 0.54560
# Epoch 6/1000
# 5815/5815 [==============================] - 903s 155ms/step - loss: 0.0554 - accuracy: 0.9801 - val_loss: 0.6745 - val_accuracy: 0.4915
#
# Epoch 00006: val_accuracy did not improve from 0.54560
# Epoch 7/1000
# 5815/5815 [==============================] - 907s 156ms/step - loss: 0.0389 - accuracy: 0.9864 - val_loss: 0.5954 - val_accuracy: 0.5255
#
# Epoch 00007: val_accuracy did not improve from 0.54560
# Epoch 8/1000
# 5815/5815 [==============================] - 909s 156ms/step - loss: 0.0291 - accuracy: 0.9902 - val_loss: 0.4444 - val_accuracy: 0.9598
#
# Epoch 00008: val_accuracy improved from 0.54560 to 0.95981, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 9/1000
# 5815/5815 [==============================] - 900s 155ms/step - loss: 0.0378 - accuracy: 0.9862 - val_loss: 0.2565 - val_accuracy: 0.9583
#
# Epoch 00009: val_accuracy did not improve from 0.95981
# Epoch 10/1000
# 5815/5815 [==============================] - 897s 154ms/step - loss: 0.0320 - accuracy: 0.9921 - val_loss: 0.1573 - val_accuracy: 0.9629
#
# Epoch 00010: val_accuracy improved from 0.95981 to 0.96291, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 11/1000
# 5815/5815 [==============================] - 889s 153ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.1255 - val_accuracy: 0.9660
#
# Epoch 00011: val_accuracy improved from 0.96291 to 0.96600, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 12/1000
# 5815/5815 [==============================] - 895s 154ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.1587 - val_accuracy: 0.9505
#
# Epoch 00012: val_accuracy did not improve from 0.96600
# Epoch 13/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 0.1027 - accuracy: 0.9680 - val_loss: 0.1944 - val_accuracy: 0.9258
#
# Epoch 00013: val_accuracy did not improve from 0.96600
# Epoch 14/1000
# 5815/5815 [==============================] - 891s 153ms/step - loss: 0.1060 - accuracy: 0.9594 - val_loss: 0.1137 - val_accuracy: 0.9629
#
# Epoch 00014: val_accuracy did not improve from 0.96600
# Epoch 15/1000
# 5815/5815 [==============================] - 894s 154ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.1145 - val_accuracy: 0.9737
#
# Epoch 00015: val_accuracy improved from 0.96600 to 0.97372, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 16/1000
# 5815/5815 [==============================] - 886s 152ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9722
#
# Epoch 00016: val_accuracy did not improve from 0.97372
# Epoch 17/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 5.9927e-04 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9737
#
# Epoch 00017: val_accuracy did not improve from 0.97372
# Epoch 18/1000
# 5815/5815 [==============================] - 895s 154ms/step - loss: 3.5862e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9706
#
# Epoch 00018: val_accuracy did not improve from 0.97372
# Epoch 19/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 2.1932e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9706
#
# Epoch 00019: val_accuracy did not improve from 0.97372
# Epoch 20/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 1.7513e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9706
#
# Epoch 00020: val_accuracy did not improve from 0.97372
# Epoch 21/1000
# 5815/5815 [==============================] - 895s 154ms/step - loss: 1.4159e-04 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9706
#
# Epoch 00021: val_accuracy did not improve from 0.97372
# Epoch 22/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 1.1576e-04 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9722
#
# Epoch 00022: val_accuracy did not improve from 0.97372
# Epoch 23/1000
# 5815/5815 [==============================] - 893s 154ms/step - loss: 9.2717e-05 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9691
#
# Epoch 00023: val_accuracy did not improve from 0.97372
# Epoch 24/1000
# 5815/5815 [==============================] - 895s 154ms/step - loss: 8.4850e-05 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9706
#
# Epoch 00024: val_accuracy did not improve from 0.97372
# Epoch 25/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 6.3809e-05 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9691
#
# Epoch 00025: val_accuracy did not improve from 0.97372
# Epoch 26/1000
# 5815/5815 [==============================] - 892s 153ms/step - loss: 5.7448e-05 - accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 0.9691
#
# Epoch 00026: val_accuracy did not improve from 0.97372
# Epoch 27/1000
# 5815/5815 [==============================] - 893s 154ms/step - loss: 5.1081e-05 - accuracy: 1.0000 - val_loss: 0.1739 - val_accuracy: 0.9691
#
# Epoch 00027: val_accuracy did not improve from 0.97372
# Epoch 28/1000
# 5815/5815 [==============================] - 894s 154ms/step - loss: 4.6962e-05 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9691
#
# Epoch 00028: val_accuracy did not improve from 0.97372
# Epoch 29/1000
# ...
#
# Epoch 00010: val_accuracy did not improve from 0.96754
# Epoch 11/1000
# 5815/5815 [==============================] - 1826s 314ms/step - loss: 0.0305 - accuracy: 0.9905 - val_loss: 0.0988 - val_accuracy: 0.9753
#
# Epoch 00011: val_accuracy improved from 0.96754 to 0.97527, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 12/1000
# 5815/5815 [==============================] - 1827s 314ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0753 - val_accuracy: 0.9768
#
# Epoch 00012: val_accuracy improved from 0.97527 to 0.97682, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 13/1000
# 5815/5815 [==============================] - 1816s 312ms/step - loss: 0.0529 - accuracy: 0.9828 - val_loss: 1.3100 - val_accuracy: 0.5889
#
# Epoch 00013: val_accuracy did not improve from 0.97682
# Epoch 14/1000
# 5815/5815 [==============================] - 1817s 312ms/step - loss: 0.2156 - accuracy: 0.9300 - val_loss: 0.1154 - val_accuracy: 0.9660
#
# Epoch 00014: val_accuracy did not improve from 0.97682
# Epoch 15/1000
# 5815/5815 [==============================] - 1817s 312ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.0931 - val_accuracy: 0.9753
#
# Epoch 00015: val_accuracy did not improve from 0.97682
# Epoch 16/1000
# 5815/5815 [==============================] - 1816s 312ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.1048 - val_accuracy: 0.9768
#
# Epoch 00016: val_accuracy did not improve from 0.97682
# Epoch 17/1000
# 5815/5815 [==============================] - 1819s 313ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1298 - val_accuracy: 0.9815
#
# Epoch 00017: val_accuracy improved from 0.97682 to 0.98145, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 18/1000
# 5815/5815 [==============================] - 1829s 314ms/step - loss: 8.3433e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9845
#
# Epoch 00018: val_accuracy improved from 0.98145 to 0.98454, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3p=20.hdf5
# Epoch 19/1000
# 5815/5815 [==============================] - 1814s 312ms/step - loss: 3.2456e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9845
#
# Epoch 00019: val_accuracy did not improve from 0.98454
# Epoch 20/1000
# 5815/5815 [==============================] - 1811s 311ms/step - loss: 2.2693e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9845
#
# Epoch 00020: val_accuracy did not improve from 0.98454
# Epoch 21/1000
# 5815/5815 [==============================] - 1817s 312ms/step - loss: 1.7553e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9845
#
# Epoch 00021: val_accuracy did not improve from 0.98454
# Epoch 22/1000
# 5815/5815 [==============================] - 1817s 313ms/step - loss: 1.3940e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9845
#
# Epoch 00022: val_accuracy did not improve from 0.98454
# Epoch 23/1000
# 5815/5815 [==============================] - 1818s 313ms/step - loss: 1.1630e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9845
#
# Epoch 00023: val_accuracy did not improve from 0.98454
# Epoch 24/1000
# 5815/5815 [==============================] - 1818s 313ms/step - loss: 1.1371e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9845
#
# Epoch 00024: val_accuracy did not improve from 0.98454
# Epoch 25/1000
# 5815/5815 [==============================] - 1816s 312ms/step - loss: 9.8190e-05 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9845
#
# Epoch 00025: val_accuracy did not improve from 0.98454
# Epoch 26/1000
# 5815/5815 [==============================] - 1818s 313ms/step - loss: 8.2495e-05 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9845
#
# Epoch 00026: val_accuracy did not improve from 0.98454
# Epoch 27/1000
# 5815/5815 [==============================] - 1815s 312ms/step - loss: 7.4617e-05 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9845
#
# Epoch 00027: val_accuracy did not improve from 0.98454
# Epoch 28/1000
# 5815/5815 [==============================] - 1819s 313ms/step - loss: 6.3884e-05 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9845
#
# Epoch 00028: val_accuracy did not improve from 0.98454
# Epoch 29/1000
# 5815/5815 [==============================] - 1823s 314ms/step - loss: 6.2513e-05 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9845
#
# Epoch 00029: val_accuracy did not improve from 0.98454
# Epoch 30/1000
# 5815/5815 [==============================] - 1819s 313ms/step - loss: 5.4879e-05 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9845
#
# Epoch 00030: val_accuracy did not improve from 0.98454
# Epoch 31/1000
# 5815/5815 [==============================] - 1820s 313ms/step - loss: 5.1597e-05 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9830
#
# Epoch 00031: val_accuracy did not improve from 0.98454
# Epoch 32/1000
# 5815/5815 [==============================] - 1820s 313ms/step - loss: 4.6087e-05 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9845
#
# Epoch 00032: val_accuracy did not improve from 0.98454
# Epoch 33/1000
# 5815/5815 [==============================] - 1820s 313ms/step - loss: 3.9024e-05 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9845
#
# Epoch 00033: val_accuracy did not improve from 0.98454
# Epoch 34/1000
# 5815/5815 [==============================] - 1818s 313ms/step - loss: 4.2249e-05 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9845
#
# Epoch 00034: val_accuracy did not improve from 0.98454
# Epoch 35/1000
# 5815/5815 [==============================] - 1813s 312ms/step - loss: 3.2860e-05 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9845
#
# Epoch 00035: val_accuracy did not improve from 0.98454
# Epoch 36/1000
# 5815/5815 [==============================] - 1822s 313ms/step - loss: 3.5318e-05 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9845
#
# Epoch 00036: val_accuracy did not improve from 0.98454
# Epoch 37/1000
# 5815/5815 [==============================] - 1819s 313ms/step - loss: 3.3580e-05 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9845
#
# Epoch 00037: val_accuracy did not improve from 0.98454
# Epoch 38/1000
# 5815/5815 [==============================] - 1817s 312ms/step - loss: 3.2620e-05 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9845
#
# Epoch 00038: val_accuracy did not improve from 0.98454
# (6462, 3101, 2, 1)
# (6462, 2)
# C:\Users\user\anaconda3\envs\tensorflow_py37\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Train on 5815 samples, validate on 647 samples
# Epoch 1/1000
# 5815/5815 [==============================] - 1719s 296ms/step - loss: 0.7768 - accuracy: 0.5546 - val_loss: 0.6955 - val_accuracy: 0.4853
#
# Epoch 00001: val_accuracy improved from -inf to 0.48532, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 2/1000
# 5815/5815 [==============================] - 1768s 304ms/step - loss: 0.4675 - accuracy: 0.7771 - val_loss: 0.7011 - val_accuracy: 0.4853
#
# Epoch 00002: val_accuracy did not improve from 0.48532
# Epoch 3/1000
# 5815/5815 [==============================] - 1743s 300ms/step - loss: 0.2267 - accuracy: 0.9092 - val_loss: 0.6920 - val_accuracy: 0.4853
#
# Epoch 00003: val_accuracy did not improve from 0.48532
# Epoch 4/1000
# 5815/5815 [==============================] - 1759s 302ms/step - loss: 0.1635 - accuracy: 0.9374 - val_loss: 0.6758 - val_accuracy: 0.4884
#
# Epoch 00004: val_accuracy improved from 0.48532 to 0.48841, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 5/1000
# 5815/5815 [==============================] - 1710s 294ms/step - loss: 0.0878 - accuracy: 0.9689 - val_loss: 0.6488 - val_accuracy: 0.5023
#
# Epoch 00005: val_accuracy improved from 0.48841 to 0.50232, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 6/1000
# 5815/5815 [==============================] - 1788s 307ms/step - loss: 0.0566 - accuracy: 0.9788 - val_loss: 0.5813 - val_accuracy: 0.9474
#
# Epoch 00006: val_accuracy improved from 0.50232 to 0.94745, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 7/1000
# 5815/5815 [==============================] - 1690s 291ms/step - loss: 0.0571 - accuracy: 0.9785 - val_loss: 0.5163 - val_accuracy: 0.9583
#
# Epoch 00007: val_accuracy improved from 0.94745 to 0.95827, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 8/1000
# 5815/5815 [==============================] - 1764s 303ms/step - loss: 0.0449 - accuracy: 0.9842 - val_loss: 0.4612 - val_accuracy: 0.7604
#
# Epoch 00008: val_accuracy did not improve from 0.95827
# Epoch 9/1000
# 5815/5815 [==============================] - 1771s 305ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.2543 - val_accuracy: 0.9335
#
# Epoch 00009: val_accuracy did not improve from 0.95827
# Epoch 10/1000
# 5815/5815 [==============================] - 1761s 303ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.1146 - val_accuracy: 0.9722
#
# Epoch 00010: val_accuracy improved from 0.95827 to 0.97218, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 11/1000
# 5815/5815 [==============================] - 1727s 297ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.0935 - val_accuracy: 0.9722
#
# Epoch 00011: val_accuracy did not improve from 0.97218
# Epoch 12/1000
# 5815/5815 [==============================] - 1725s 297ms/step - loss: 0.0151 - accuracy: 0.9945 - val_loss: 0.1350 - val_accuracy: 0.9645
#
# Epoch 00012: val_accuracy did not improve from 0.97218
# Epoch 13/1000
# 5815/5815 [==============================] - 1712s 294ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.1142 - val_accuracy: 0.9737
#
# Epoch 00013: val_accuracy improved from 0.97218 to 0.97372, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 14/1000
# 5815/5815 [==============================] - 1743s 300ms/step - loss: 0.0141 - accuracy: 0.9947 - val_loss: 0.1588 - val_accuracy: 0.9614
#
# Epoch 00014: val_accuracy did not improve from 0.97372
# Epoch 15/1000
# 5815/5815 [==============================] - 1745s 300ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.1723 - val_accuracy: 0.9660
#
# Epoch 00015: val_accuracy did not improve from 0.97372
# Epoch 16/1000
# 5815/5815 [==============================] - 1749s 301ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.1459 - val_accuracy: 0.9691
#
# Epoch 00016: val_accuracy did not improve from 0.97372
# Epoch 17/1000
# 5815/5815 [==============================] - 1733s 298ms/step - loss: 0.2647 - accuracy: 0.9173 - val_loss: 0.1068 - val_accuracy: 0.9660
#
# Epoch 00017: val_accuracy did not improve from 0.97372
# Epoch 18/1000
# 5815/5815 [==============================] - 1761s 303ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0934 - val_accuracy: 0.9722
#
# Epoch 00018: val_accuracy did not improve from 0.97372
# Epoch 19/1000
# 5815/5815 [==============================] - 1760s 303ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.0950 - val_accuracy: 0.9768
#
# Epoch 00019: val_accuracy improved from 0.97372 to 0.97682, saving model to ./model/GoogLeNet_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3p=20.hdf5
# Epoch 20/1000
# 5815/5815 [==============================] - 1733s 298ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.1004 - val_accuracy: 0.9768
#
# Epoch 00020: val_accuracy did not improve from 0.97682
# Epoch 21/1000
# 5815/5815 [==============================] - 1742s 300ms/step - loss: 4.6447e-04 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 0.9768
#
# Epoch 00021: val_accuracy did not improve from 0.97682
# Epoch 22/1000
# 5815/5815 [==============================] - 1750s 301ms/step - loss: 3.3152e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9737
#
# Epoch 00022: val_accuracy did not improve from 0.97682
# Epoch 23/1000
# 5815/5815 [==============================] - 1746s 300ms/step - loss: 2.5543e-04 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9753
#
# Epoch 00023: val_accuracy did not improve from 0.97682
# Epoch 24/1000
# 5815/5815 [==============================] - 1743s 300ms/step - loss: 2.0033e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9753
#
# Epoch 00024: val_accuracy did not improve from 0.97682
# Epoch 25/1000
# 5815/5815 [==============================] - 1756s 302ms/step - loss: 1.5333e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9753
#
# Epoch 00025: val_accuracy did not improve from 0.97682
# Epoch 26/1000
# 5815/5815 [==============================] - 1731s 298ms/step - loss: 1.3194e-04 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9753
#
# Epoch 00026: val_accuracy did not improve from 0.97682
# Epoch 27/1000
# 5815/5815 [==============================] - 1748s 301ms/step - loss: 1.2015e-04 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9737
#
# Epoch 00027: val_accuracy did not improve from 0.97682
# Epoch 28/1000
# 5815/5815 [==============================] - 1775s 305ms/step - loss: 1.0497e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9753
#
# Epoch 00028: val_accuracy did not improve from 0.97682
# Epoch 29/1000
# 5815/5815 [==============================] - 1747s 300ms/step - loss: 9.1509e-05 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9753
#
# Epoch 00029: val_accuracy did not improve from 0.97682
# Epoch 30/1000
# 5815/5815 [==============================] - 1756s 302ms/step - loss: 7.7566e-05 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9753
#
# Epoch 00030: val_accuracy did not improve from 0.97682
# Epoch 31/1000
# 5815/5815 [==============================] - 1745s 300ms/step - loss: 7.3434e-05 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9753
#
# Epoch 00031: val_accuracy did not improve from 0.97682
# Epoch 32/1000
# 5815/5815 [==============================] - 1759s 302ms/step - loss: 6.6927e-05 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9753
#
# Epoch 00032: val_accuracy did not improve from 0.97682
# Epoch 33/1000
# 5815/5815 [==============================] - 1754s 302ms/step - loss: 5.6138e-05 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9753
#
# Epoch 00033: val_accuracy did not improve from 0.97682
# Epoch 34/1000
# 5815/5815 [==============================] - 1764s 303ms/step - loss: 5.9428e-05 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9753
#
# Epoch 00034: val_accuracy did not improve from 0.97682
# Epoch 35/1000
# 5815/5815 [==============================] - 1771s 305ms/step - loss: 4.4602e-05 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9753
#
# Epoch 00035: val_accuracy did not improve from 0.97682
# Epoch 36/1000
# 5815/5815 [==============================] - 1744s 300ms/step - loss: 4.4639e-05 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9753
#
# Epoch 00036: val_accuracy did not improve from 0.97682
# Epoch 37/1000
# 5815/5815 [==============================] - 1756s 302ms/step - loss: 4.1486e-05 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9753
#
# Epoch 00037: val_accuracy did not improve from 0.97682
# Epoch 38/1000
# 5815/5815 [==============================] - 1738s 299ms/step - loss: 3.8457e-05 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9753
#
# Epoch 00038: val_accuracy did not improve from 0.97682
# Epoch 39/1000
#  200/5815 [>.............................] - ETA: 26:22 - loss: 3.0153e-05 - accuracy: 1.0000
