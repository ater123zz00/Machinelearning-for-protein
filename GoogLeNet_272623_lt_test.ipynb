# %%
import sys
print(sys.version)
print(sys.executable)
import tensorflow as tf
tf.__version__
# Out:
# 3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]
# C:\Users\user\anaconda3\envs\tensorflow_py37\python.exe
# '2.0.0'

# %%
import numpy as np
import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()
import os
from sklearn.model_selection import train_test_split
import random
import keras
from tensorflow.python.framework import ops
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPool2D,MaxPooling2D,GlobalAveragePooling2D,AveragePooling2D,Input, concatenate
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
import itertools
from keras.models import Model,load_model
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import tensorflow.keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
def get_data(k1_n):
    if k1_n == 1:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1.dat'
    if k1_n == 2:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2.dat'
    if k1_n == 3:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt3.dat'
    if k1_n == 4:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 5:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 6:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 7:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-balance-272623_peptide_nm1_lt1lt3.dat'

    if k1_n == 8:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1.dat'
    if k1_n == 9:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2.dat'
    if k1_n == 10:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt3.dat'
    if k1_n == 11:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 12:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 13:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 14:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-LeftRight-seed0-272623_peptide_nm1_lt1lt3.dat'
    
    if k1_n == 15:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1.dat'
    if k1_n == 16:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2.dat'
    if k1_n == 17:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt3.dat'
    if k1_n == 18:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 19:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 20:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 21:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3.dat'
        
    if k1_n == 22:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1.dat'
    if k1_n == 23:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2.dat'
    if k1_n == 24:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt3.dat'
    if k1_n == 25:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 26:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 27:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 28:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K3-272623_peptide_nm1_lt1lt3.dat'

    if k1_n == 29:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1.dat'
    if k1_n == 30:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2.dat'
    if k1_n == 31:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt3.dat'
    if k1_n == 32:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt2.dat'
    if k1_n == 33:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt2lt3.dat'
    if k1_n == 34:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1_lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1_lt3.dat'    
    if k1_n == 35:
        ver = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3.hdf5'
        data = '272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K5-272623_peptide_nm1_lt1lt3.dat'
        
    data_path = './272623/data/'
    test_path = data_path+data
    model_path ='./model/GoogLeNet_lt/'+ver
    return test_path,model_path

# %%
def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1

    return one_hot_encode

# %%
def deal_data(train_path):
    y_test= list()
    X_test= list()
    f = open(test_path,'r')
    s = f.read()
    f.close()
    data_test = s.split("\n")
    data_test.pop()
    random.shuffle(data_test)
    for i in data_test:
        data_t = i.split(" ",1)
        y_test.append(data_t[0])
        X_test.append(data_t[1])

    data_x_test = list()
    for i in range(0,len(X_test)):
        data_t2 = X_test[i].split(" ")
        data_t2.pop()
        #print(len(data_t2))
        data_x_test.append(np.zeros( len(data_t2) ))
        for i_2 in data_t2:
            temp = i_2.split(":")
            temp[0] = int(temp[0])-1
            temp[1] = float(temp[1])
            data_x_test[i][temp[0]] = temp[1]
            #print(type(temp[0]) )
            #print(type(temp[1]) )
   
    X_test = np.array(data_x_test)
    y_test_label = np.array(y_test)
    
    len_type = int( (len(data_x_test[0]))/2) 

  
    X_test = np.reshape(X_test,  [-1,len_type,2,1])
    y_test_onehot = to_categorical(y_test_label)

    print(X_test.shape)
    print(y_test_onehot.shape)
    return len_type,X_test,y_test_onehot

# %%
for k in range(15,36):
    test_path,model_path = get_data(k)
    len_type,X_test,y_test_onehot = deal_data(test_path)
    
    model = load_model(model_path)
    y_pred =  model.predict(X_test,verbose=1)
    
    # 數值評估
    y_len = len(y_pred)
    y_pred_class = np.zeros((y_len,2),dtype=np.int)
    for i in range(0,y_len):
        if (y_pred[i][0] > y_pred[i][1]):
            y_pred_class[i][0] = 1
        else:
            y_pred_class[i][1] = 1
    
    TP=0
    FP=0
    TN=0
    FN=0
    acc=0
    Sen=0
    Pre=0
    
    for i in range(0,y_len):
        if(y_pred_class[i][0] == y_test_onehot[i][0]):
            if(y_pred_class[i][0] == 0):
                TP += 1
            else:
                TN +=1
        else:
            if(y_pred_class[i][0] == 1):
                FP += 1
            else:
                FN +=1
    acc = (TP+TN)/(TP+TN+FP+FN)
    if(TP != 0):Sen = TP/(TP+FN)
    if(TP != 0):Pre = TP/(TP+FP)
    '''
    print(TP)
    print(TN)
    print(FP)
    print(FN)
    print(acc)
    print(Sen)
    print(Pre)
    '''
    print('Test accuracy:', acc)
    
    with open(model_path+'_result.txt',"w") as f:
        f.write('Test accuracy:' + str(acc) + '\n')
        f.write('Test TP:' + str(TP) + '\n')
        f.write('Test FP:' + str(FP) + '\n')
        f.write('Test TN:' + str(TN) + '\n')
        f.write('Test FN:' + str(FN) + '\n')
        f.write('Test Sen:' + str(Sen) + '\n')
        f.write('Test Pre:' + str(Pre) + '\n')
# Out:
# (1621, 100, 2, 1)
# (1621, 2)
# 1621/1621 [==============================] - 1s 415us/step
# Test accuracy: 0.7501542257865516
# (1621, 988, 2, 1)
# (1621, 2)
# 1621/1621 [==============================] - 1s 898us/step
# Test accuracy: 0.7772979642196175
# (1621, 3001, 2, 1)
# (1621, 2)
# 1621/1621 [==============================] - 3s 2ms/step
# Test accuracy: 0.7483035163479334
# (1621, 1088, 2, 1)
# (1621, 2)
# 1621/1621 [==============================] - 1s 911us/step
# Test accuracy: 0.7735965453423812
# (1621, 4089, 2, 1)
# (1621, 2)
# 1621/1621 [==============================] - 3s 2ms/step
# Test accuracy: 0.756940160394818
# (2541, 100, 2, 1)
# (2541, 2)
# 2541/2541 [==============================] - 2s 623us/step
# Test accuracy: 0.7898465171192444
# (2541, 988, 2, 1)
# (2541, 2)
# 2541/2541 [==============================] - 6s 2ms/step
# Test accuracy: 0.7839433293978748
# (2541, 3001, 2, 1)
# (2541, 2)
# 2541/2541 [==============================] - 13s 5ms/step
# Test accuracy: 0.7898465171192444
# (2541, 1088, 2, 1)
# (2541, 2)
# 2541/2541 [==============================] - 4s 1ms/step
# Test accuracy: 0.8012593467138922
# (2541, 4089, 2, 1)
# (2541, 2)
# 2541/2541 [==============================] - 11s 4ms/step
# Test accuracy: 0.7977174340810704
# (1694, 100, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 3s 2ms/step
# Test accuracy: 0.5
# (1694, 988, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 5s 3ms/step
# Test accuracy: 0.9138134592680047
# (1694, 3001, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 14s 9ms/step
# Test accuracy: 0.9327036599763873
# (1694, 1088, 2, 1)
# (1694, 2)
# 1694/1694 [==============================] - 6s 4ms/step
# Test accuracy: 0.9031877213695395
# (1694, 4089, 2, 1)
# (1694, 2)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-d07331f2a4d5> in <module>
#       5     len_type,X_test,y_test_onehot = deal_data(test_path)
#       6
# ----> 7     model = load_model(model_path)
#       8     y_pred =  model.predict(X_test,verbose=1)
#       9
#
# ~\anaconda3\envs\tensorflow_py37\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\anaconda3\envs\tensorflow_py37\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     581
#     582     if H5Dict.is_supported_type(filepath):
# --> 583         with H5Dict(filepath, mode='r') as h5dict:
#     584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# ~\anaconda3\envs\tensorflow_py37\lib\site-packages\keras\utils\io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# ~\anaconda3\envs\tensorflow_py37\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~\anaconda3\envs\tensorflow_py37\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = './model/DNN_lt/272623-10.5-11.0-train-Valid-cdhit60-Ushuffle-seed0-K1-272623_peptide_nm1_lt1lt3.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
